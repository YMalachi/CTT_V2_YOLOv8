# %%
from ultralytics import YOLO
from IPython.display import Image, display
import os

# Load base model
model = YOLO("yolov8s.pt")

# Train
model.train(
    data="C:\CTT_V2_YOLOv8\data\yolo_dataset\data.yaml",
    epochs=30,
    imgsz=640
)
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\C'
# <>:13: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Yotam\AppData\Local\Temp\ipykernel_14368\1682307387.py:13: SyntaxWarning: invalid escape sequence '\C'
#   data="C:\CTT_V2_YOLOv8\data\yolo_dataset\data.yaml",
# Ultralytics 8.3.107  Python-3.12.6 torch-2.6.0+cpu CPU (Intel Core(TM) i5-9600KF 3.70GHz)
# ...

# %%
# Run detection on each frame
for frame_path in frames:
    results = model(frame_path, save=True, conf=0.3)
    print(f"Processed: {frame_path}")
# Out:
# image 1/1 C:\CTT_V2_YOLOv8\notebooks\..\data\test_frames\test1.jpg: 384x640 2 sports balls, 1 apple, 211.7ms
# Speed: 1.8ms preprocess, 211.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\CTT_V2_YOLOv8\runs\detect\predict3
# Processed: ../data/test_frames\test1.jpg
#
# image 1/1 C:\CTT_V2_YOLOv8\notebooks\..\data\test_frames\test2.jpg: 384x640 2 sports balls, 179.0ms
# Speed: 2.9ms preprocess, 179.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\CTT_V2_YOLOv8\runs\detect\predict3
# Processed: ../data/test_frames\test2.jpg
#
# image 1/1 C:\CTT_V2_YOLOv8\notebooks\..\data\test_frames\test3.jpg: 384x640 6 sports balls, 179.4ms
# Speed: 2.3ms preprocess, 179.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\CTT_V2_YOLOv8\runs\detect\predict3
# Processed: ../data/test_frames\test3.jpg
#
# ...

# %%
# Show result images from the YOLO output folder
result_dir = "../runs/detect/predict"
for img_file in os.listdir(result_dir):
    display(Image(filename=os.path.join(result_dir, img_file)))
